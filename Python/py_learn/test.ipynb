# %%
'''
分段函数求值

        3x - 5  (x > 1)
f(x) =  x + 2   (-1 <= x <= 1)
        5x + 3  (x < -1)

Version: 0.1
Author: 王成
'''

def func(x):
    if x > 1:
        return 3 * x - 5
    elif x >= -1:
        return x + 2
    else:
        return 5 * x + 3
    
if __name__ == '__main__':
    x = float(input('x = '))
    print('f(x) =', func(x))
# Out:
# f(x) = 3.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义时间和两个周期性函数
t = np.linspace(0, 2 * np.pi, 500)
f_t = np.sin(t)  # 函数 1
g_t = np.cos(2 * t)  # 函数 2

# 绘制函数波形
plt.figure(figsize=(10, 5))
plt.plot(t, f_t, label='f(t) = sin(t)')
plt.plot(t, g_t, label='g(t) = cos(2t)', linestyle='--')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.title('Waveforms of Two Periodic Functions')
plt.legend()
plt.grid(True)
plt.show()

# 绘制相图
plt.figure(figsize=(5, 5))
plt.plot(f_t, g_t, label='Parametric plot of f(t) and g(t)')
plt.xlabel('f(t)')
plt.ylabel('g(t)')
plt.title('Phase Diagram')
plt.legend()
plt.grid(True)
plt.show()
